# %% [markdown]
# <a href="https://colab.research.google.com/github/HecMartinSol/03MAIR-Alg.Optimizacion/blob/master/AG1/hector_martin_solis_AG1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# AG1 - Actividad guiada
#
# Héctor Martín Solís
#
# https://colab.research.google.com/drive/1r1uYKWQxgpBf91SYkpddH3oSrkPPwBrq

# %%
import time
# DECORADOR PARA MEDIR EL TIEMPO DE LOS ALGORITMOS
def timer_decorator(method):
    def measure_time(*args, **kw):
        time_begin = time.time()
        result = method(*args, **kw)
        time_end = time.time()
        ms_elapsed = (time_end - time_begin) * 1000

        if 'log_time' in kw:
            name = kw.get('log_name', method.__name__.upper())
            kw['log_time'][name] = ms_elapsed
        else:
            print(method.__name__, "lasted", ms_elapsed, "ms")

        return result
    return measure_time

# %%
# DIVIDE Y VENCERAS - LAS TORRES DE HANOI
def hanoi(fichas, origen, destino):
  if fichas == 1:
    print("Llevar la ficha de", origen, "a", destino)
  else:
    hanoi(fichas - 1, origen, 6 - origen - destino)
    print("Llevar la ficha de", origen, "a", destino)
    hanoi(fichas - 1, 6 - origen - destino, destino)


@timer_decorator 
def measure_hanoi(**kwargs):
  hanoi(5,1,3)

time_info ={}
measure_hanoi(log_time=time_info)

print(time_info)
# Out:
# Llevar la ficha de 1 a 3
# Llevar la ficha de 1 a 2
# Llevar la ficha de 3 a 2
# Llevar la ficha de 1 a 3
# Llevar la ficha de 2 a 1
# Llevar la ficha de 2 a 3
# Llevar la ficha de 1 a 3
# Llevar la ficha de 1 a 2
# Llevar la ficha de 3 a 2
# Llevar la ficha de 3 a 1
# Llevar la ficha de 2 a 1
# Llevar la ficha de 3 a 2
# Llevar la ficha de 1 a 3
# Llevar la ficha de 1 a 2
# Llevar la ficha de 3 a 2
# Llevar la ficha de 1 a 3
# Llevar la ficha de 2 a 1
# Llevar la ficha de 2 a 3
# Llevar la ficha de 1 a 3
# Llevar la ficha de 2 a 1
# Llevar la ficha de 3 a 2
# Llevar la ficha de 3 a 1
# Llevar la ficha de 2 a 1
# Llevar la ficha de 2 a 3
# Llevar la ficha de 1 a 3
# Llevar la ficha de 1 a 2
# Llevar la ficha de 3 a 2
# Llevar la ficha de 1 a 3
# Llevar la ficha de 2 a 1
# Llevar la ficha de 2 a 3
# Llevar la ficha de 1 a 3
# {'MEASURE_HANOI': 16.055822372436523}

# %%
# VUELTA ATRAS: problema de las reinas
def reinas(N, solucion, etapa):
    for i in range(1, N + 1):
        solucion[etapa] = i
        # print(solucion)

        if es_prometedor(solucion, etapa) : 
            if etapa == N - 1:
                print("Solucion posible para N =",N,":", solucion)
                return solucion
            else:
                # print("-> [P] prometedora")
                reinas(N, solucion, etapa + 1)
        else:
            # print("-> [N] no prometedora")
            pass
    
        solucion[etapa] = 0



def es_prometedor(solucion, etapa) : 
    # si la solucion tiene dos valores iguales no es valida
    for i in range(etapa + 1):
        if solucion.count(solucion[i]) > 1:
            return False

        # diagonales
        for j in range(i+1, etapa + 1):
            # print("comprueba diagonal de ", i , "y", j)
            if abs(i-j) == abs(solucion[i] - solucion[j]):
                return False
    
    return True

@timer_decorator 
def measure_queens(N, **kwargs):
  solution = []
  for i in range(N):
    solution.append(0)
  reinas(N, solution, 0)

for N in range(10):
  time_info ={"N":N}
  measure_queens(N, log_time=time_info)
  print(time_info)
# Out:
# {'N': 0, 'MEASURE_QUEENS': 0.00286102294921875}
# Solucion posible para N = 1 : [1]
# {'N': 1, 'MEASURE_QUEENS': 0.8840560913085938}
# {'N': 2, 'MEASURE_QUEENS': 0.019073486328125}
# {'N': 3, 'MEASURE_QUEENS': 0.026226043701171875}
# Solucion posible para N = 4 : [2, 4, 1, 3]
# {'N': 4, 'MEASURE_QUEENS': 0.4558563232421875}
# Solucion posible para N = 5 : [1, 3, 5, 2, 4]
# Solucion posible para N = 5 : [2, 5, 3, 1, 4]
# {'N': 5, 'MEASURE_QUEENS': 0.7452964782714844}
# Solucion posible para N = 6 : [2, 4, 6, 1, 3, 5]
# Solucion posible para N = 6 : [3, 6, 2, 5, 1, 4]
# Solucion posible para N = 6 : [5, 3, 1, 6, 4, 2]
# {'N': 6, 'MEASURE_QUEENS': 2.3021697998046875}
# Solucion posible para N = 7 : [1, 3, 5, 7, 2, 4, 6]
# Solucion posible para N = 7 : [2, 4, 1, 7, 5, 3, 6]
# Solucion posible para N = 7 : [2, 5, 1, 4, 7, 3, 6]
# Solucion posible para N = 7 : [2, 5, 3, 1, 7, 4, 6]
# Solucion posible para N = 7 : [2, 5, 7, 4, 1, 3, 6]
# Solucion posible para N = 7 : [2, 7, 5, 3, 1, 6, 4]
# Solucion posible para N = 7 : [3, 1, 6, 2, 5, 7, 4]
# Solucion posible para N = 7 : [3, 5, 7, 2, 4, 6, 1]
# Solucion posible para N = 7 : [4, 7, 3, 6, 2, 5, 1]
# Solucion posible para N = 7 : [5, 2, 6, 3, 7, 4, 1]
# Solucion posible para N = 7 : [6, 4, 2, 7, 5, 3, 1]
# {'N': 7, 'MEASURE_QUEENS': 8.347034454345703}
# Solucion posible para N = 8 : [1, 5, 8, 6, 3, 7, 2, 4]
# Solucion posible para N = 8 : [2, 5, 7, 1, 3, 8, 6, 4]
# Solucion posible para N = 8 : [2, 6, 1, 7, 4, 8, 3, 5]
# Solucion posible para N = 8 : [2, 6, 8, 3, 1, 4, 7, 5]
# Solucion posible para N = 8 : [2, 7, 3, 6, 8, 5, 1, 4]
# Solucion posible para N = 8 : [2, 7, 5, 8, 1, 4, 6, 3]
# Solucion posible para N = 8 : [4, 2, 5, 8, 6, 1, 3, 7]
# Solucion posible para N = 8 : [4, 2, 8, 5, 7, 1, 3, 6]
# Solucion posible para N = 8 : [4, 7, 1, 8, 5, 2, 6, 3]
# Solucion posible para N = 8 : [4, 8, 1, 5, 7, 2, 6, 3]
# Solucion posible para N = 8 : [4, 8, 5, 3, 1, 7, 2, 6]
# Solucion posible para N = 8 : [5, 1, 8, 4, 2, 7, 3, 6]
# Solucion posible para N = 8 : [5, 2, 8, 1, 4, 7, 3, 6]
# Solucion posible para N = 8 : [5, 3, 1, 6, 8, 2, 4, 7]
# Solucion posible para N = 8 : [5, 8, 4, 1, 3, 6, 2, 7]
# Solucion posible para N = 8 : [6, 1, 5, 2, 8, 3, 7, 4]
# Solucion posible para N = 8 : [6, 2, 7, 1, 3, 5, 8, 4]
# Solucion posible para N = 8 : [6, 3, 1, 7, 5, 8, 2, 4]
# Solucion posible para N = 8 : [6, 3, 7, 2, 8, 5, 1, 4]
# Solucion posible para N = 8 : [7, 1, 3, 8, 6, 4, 2, 5]
# Solucion posible para N = 8 : [7, 2, 4, 1, 8, 5, 3, 6]
# Solucion posible para N = 8 : [7, 4, 2, 5, 8, 1, 3, 6]
# Solucion posible para N = 8 : [8, 2, 4, 1, 7, 5, 3, 6]
# Solucion posible para N = 8 : [8, 2, 5, 3, 1, 7, 4, 6]
# {'N': 8, 'MEASURE_QUEENS': 33.45131874084473}
# Solucion posible para N = 9 : [1, 3, 6, 8, 2, 4, 9, 7, 5]
# Solucion posible para N = 9 : [1, 4, 2, 8, 6, 9, 3, 5, 7]
# Solucion posible para N = 9 : [1, 4, 6, 3, 9, 2, 8, 5, 7]
# Solucion posible para N = 9 : [1, 4, 6, 8, 2, 5, 3, 9, 7]
# Solucion posible para N = 9 : [1, 4, 7, 3, 8, 2, 5, 9, 6]
# Solucion posible para N = 9 : [1, 4, 8, 3, 9, 7, 5, 2, 6]
# Solucion posible para N = 9 : [1, 5, 7, 2, 6, 3, 9, 4, 8]
# Solucion posible para N = 9 : [1, 6, 4, 2, 7, 9, 3, 5, 8]
# Solucion posible para N = 9 : [1, 7, 4, 6, 9, 2, 5, 3, 8]
# Solucion posible para N = 9 : [2, 4, 1, 7, 9, 6, 3, 5, 8]
# Solucion posible para N = 9 : [2, 4, 9, 7, 5, 3, 1, 6, 8]
# Solucion posible para N = 9 : [2, 5, 7, 4, 1, 3, 9, 6, 8]
# Solucion posible para N = 9 : [2, 5, 7, 9, 3, 6, 4, 1, 8]
# Solucion posible para N = 9 : [2, 5, 7, 9, 4, 8, 1, 3, 6]
# Solucion posible para N = 9 : [2, 5, 8, 6, 9, 3, 1, 4, 7]
# Solucion posible para N = 9 : [2, 5, 9, 4, 1, 8, 6, 3, 7]
# Solucion posible para N = 9 : [2, 6, 9, 3, 5, 8, 4, 1, 7]
# Solucion posible para N = 9 : [2, 8, 5, 3, 9, 6, 4, 1, 7]
# Solucion posible para N = 9 : [2, 8, 6, 9, 3, 1, 4, 7, 5]
# Solucion posible para N = 9 : [2, 9, 5, 3, 8, 4, 7, 1, 6]
# Solucion posible para N = 9 : [3, 1, 4, 7, 9, 2, 5, 8, 6]
# Solucion posible para N = 9 : [3, 1, 8, 4, 9, 7, 5, 2, 6]
# Solucion posible para N = 9 : [3, 1, 9, 7, 5, 2, 8, 6, 4]
# Solucion posible para N = 9 : [3, 5, 8, 2, 9, 6, 1, 7, 4]
# Solucion posible para N = 9 : [3, 6, 8, 5, 1, 9, 7, 2, 4]
# Solucion posible para N = 9 : [3, 6, 9, 2, 5, 7, 4, 1, 8]
# Solucion posible para N = 9 : [3, 6, 9, 7, 1, 4, 2, 5, 8]
# Solucion posible para N = 9 : [3, 7, 4, 2, 9, 6, 1, 5, 8]
# Solucion posible para N = 9 : [3, 9, 6, 2, 5, 7, 1, 4, 8]
# Solucion posible para N = 9 : [3, 9, 6, 4, 1, 7, 5, 2, 8]
# Solucion posible para N = 9 : [4, 1, 3, 6, 9, 2, 8, 5, 7]
# Solucion posible para N = 9 : [4, 1, 5, 2, 9, 7, 3, 8, 6]
# Solucion posible para N = 9 : [4, 1, 9, 6, 3, 7, 2, 8, 5]
# Solucion posible para N = 9 : [4, 2, 7, 9, 1, 5, 8, 6, 3]
# Solucion posible para N = 9 : [4, 2, 8, 3, 9, 7, 5, 1, 6]
# Solucion posible para N = 9 : [4, 2, 9, 3, 6, 8, 1, 5, 7]
# Solucion posible para N = 9 : [4, 2, 9, 5, 1, 8, 6, 3, 7]
# Solucion posible para N = 9 : [4, 6, 1, 5, 2, 8, 3, 7, 9]
# Solucion posible para N = 9 : [4, 6, 8, 2, 7, 1, 3, 5, 9]
# Solucion posible para N = 9 : [4, 6, 8, 3, 1, 7, 5, 2, 9]
# Solucion posible para N = 9 : [4, 7, 1, 8, 5, 2, 9, 3, 6]
# Solucion posible para N = 9 : [4, 7, 3, 8, 2, 5, 9, 6, 1]
# Solucion posible para N = 9 : [4, 7, 3, 8, 6, 2, 9, 5, 1]
# Solucion posible para N = 9 : [4, 7, 5, 2, 9, 6, 8, 3, 1]
# Solucion posible para N = 9 : [4, 7, 9, 2, 5, 8, 1, 3, 6]
# Solucion posible para N = 9 : [4, 9, 3, 6, 2, 7, 5, 1, 8]
# Solucion posible para N = 9 : [4, 9, 5, 3, 1, 7, 2, 8, 6]
# Solucion posible para N = 9 : [5, 1, 6, 4, 2, 8, 3, 9, 7]
# Solucion posible para N = 9 : [5, 1, 8, 4, 2, 7, 9, 6, 3]
# Solucion posible para N = 9 : [5, 1, 8, 6, 3, 7, 2, 4, 9]
# Solucion posible para N = 9 : [5, 2, 4, 9, 7, 3, 1, 6, 8]
# Solucion posible para N = 9 : [5, 2, 6, 1, 3, 7, 9, 4, 8]
# Solucion posible para N = 9 : [5, 2, 6, 9, 3, 8, 4, 7, 1]
# Solucion posible para N = 9 : [5, 2, 8, 1, 4, 7, 9, 6, 3]
# Solucion posible para N = 9 : [5, 2, 8, 1, 7, 9, 3, 6, 4]
# Solucion posible para N = 9 : [5, 2, 8, 3, 7, 9, 1, 6, 4]
# Solucion posible para N = 9 : [5, 2, 9, 1, 6, 8, 3, 7, 4]
# Solucion posible para N = 9 : [5, 3, 1, 6, 2, 9, 7, 4, 8]
# Solucion posible para N = 9 : [5, 3, 6, 9, 2, 8, 1, 4, 7]
# Solucion posible para N = 9 : [5, 3, 8, 4, 2, 9, 6, 1, 7]
# Solucion posible para N = 9 : [5, 3, 8, 6, 2, 9, 1, 4, 7]
# Solucion posible para N = 9 : [5, 3, 9, 4, 2, 8, 6, 1, 7]
# Solucion posible para N = 9 : [5, 3, 9, 6, 8, 2, 4, 1, 7]
# Solucion posible para N = 9 : [5, 8, 1, 4, 7, 3, 6, 9, 2]
# Solucion posible para N = 9 : [5, 8, 1, 9, 4, 2, 7, 3, 6]
# Solucion posible para N = 9 : [5, 8, 2, 7, 3, 1, 9, 4, 6]
# Solucion posible para N = 9 : [5, 8, 2, 9, 3, 1, 7, 4, 6]
# Solucion posible para N = 9 : [5, 9, 2, 4, 7, 3, 8, 6, 1]
# Solucion posible para N = 9 : [5, 9, 4, 6, 8, 2, 7, 1, 3]
# Solucion posible para N = 9 : [6, 1, 5, 2, 9, 7, 4, 8, 3]
# Solucion posible para N = 9 : [6, 1, 5, 7, 9, 4, 2, 8, 3]
# Solucion posible para N = 9 : [6, 2, 5, 7, 9, 4, 8, 1, 3]
# Solucion posible para N = 9 : [6, 2, 9, 5, 3, 8, 4, 7, 1]
# Solucion posible para N = 9 : [6, 3, 1, 4, 7, 9, 2, 5, 8]
# Solucion posible para N = 9 : [6, 3, 1, 8, 4, 9, 7, 5, 2]
# Solucion posible para N = 9 : [6, 3, 9, 2, 5, 8, 1, 7, 4]
# Solucion posible para N = 9 : [6, 3, 9, 4, 1, 8, 2, 5, 7]
# Solucion posible para N = 9 : [6, 4, 2, 8, 5, 3, 1, 9, 7]
# Solucion posible para N = 9 : [6, 4, 2, 8, 5, 9, 1, 3, 7]
# Solucion posible para N = 9 : [6, 4, 9, 1, 3, 7, 2, 8, 5]
# Solucion posible para N = 9 : [6, 4, 9, 5, 8, 2, 7, 3, 1]
# Solucion posible para N = 9 : [6, 8, 2, 7, 1, 3, 5, 9, 4]
# Solucion posible para N = 9 : [6, 8, 3, 1, 9, 2, 5, 7, 4]
# Solucion posible para N = 9 : [6, 8, 3, 7, 9, 2, 5, 1, 4]
# Solucion posible para N = 9 : [6, 9, 3, 1, 8, 4, 2, 7, 5]
# Solucion posible para N = 9 : [6, 9, 7, 4, 1, 8, 2, 5, 3]
# Solucion posible para N = 9 : [7, 1, 6, 2, 5, 8, 4, 9, 3]
# Solucion posible para N = 9 : [7, 2, 4, 1, 8, 5, 9, 6, 3]
# Solucion posible para N = 9 : [7, 2, 4, 9, 1, 8, 5, 3, 6]
# Solucion posible para N = 9 : [7, 2, 8, 6, 1, 3, 5, 9, 4]
# Solucion posible para N = 9 : [7, 3, 1, 9, 5, 8, 2, 4, 6]
# Solucion posible para N = 9 : [7, 3, 8, 2, 4, 6, 9, 5, 1]
# Solucion posible para N = 9 : [7, 3, 8, 6, 2, 9, 5, 1, 4]
# Solucion posible para N = 9 : [7, 5, 1, 8, 6, 3, 9, 2, 4]
# Solucion posible para N = 9 : [7, 5, 2, 8, 1, 3, 9, 6, 4]
# Solucion posible para N = 9 : [7, 5, 3, 9, 6, 8, 2, 4, 1]
# Solucion posible para N = 9 : [7, 5, 8, 2, 9, 3, 6, 4, 1]
# Solucion posible para N = 9 : [7, 9, 3, 5, 2, 8, 6, 4, 1]
# Solucion posible para N = 9 : [8, 2, 5, 7, 1, 4, 6, 9, 3]
# Solucion posible para N = 9 : [8, 2, 9, 6, 3, 1, 4, 7, 5]
# Solucion posible para N = 9 : [8, 3, 1, 4, 7, 9, 6, 2, 5]
# Solucion posible para N = 9 : [8, 3, 5, 2, 9, 6, 4, 7, 1]
# Solucion posible para N = 9 : [8, 4, 1, 7, 5, 2, 6, 9, 3]
# Solucion posible para N = 9 : [8, 4, 7, 9, 2, 6, 1, 3, 5]
# Solucion posible para N = 9 : [8, 4, 9, 7, 3, 1, 6, 2, 5]
# Solucion posible para N = 9 : [8, 6, 1, 3, 7, 9, 4, 2, 5]
# Solucion posible para N = 9 : [8, 6, 3, 9, 7, 1, 4, 2, 5]
# Solucion posible para N = 9 : [9, 2, 5, 7, 1, 3, 8, 6, 4]
# Solucion posible para N = 9 : [9, 3, 6, 2, 7, 5, 1, 8, 4]
# Solucion posible para N = 9 : [9, 5, 3, 1, 7, 2, 8, 6, 4]
# Solucion posible para N = 9 : [9, 5, 8, 4, 1, 7, 2, 6, 3]
# Solucion posible para N = 9 : [9, 6, 2, 7, 1, 3, 5, 8, 4]
# Solucion posible para N = 9 : [9, 6, 3, 7, 2, 8, 5, 1, 4]
# Solucion posible para N = 9 : [9, 7, 3, 8, 2, 5, 1, 6, 4]
# {'N': 9, 'MEASURE_QUEENS': 210.13617515563965}
