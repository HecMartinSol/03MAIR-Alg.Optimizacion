# %% [markdown]
# <a href="https://colab.research.google.com/github/HecMartinSol/03MAIR-Alg.Optimizacion/blob/master/AG1/hector_martin_solis_AG1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# AG1 - Actividad guiada
#
# Héctor Martín Solís
#
# https://colab.research.google.com/drive/1r1uYKWQxgpBf91SYkpddH3oSrkPPwBrq

# %%
# DIVIDE Y VENCERAS - LAS TORRES DE HANOI
def hanoi(fichas, origen, destino):
  if fichas == 1:
    print("Llevar la ficha de", origen, "a", destino)
  else:
    hanoi(fichas - 1, origen, 6 - origen - destino)
    print("Llevar la ficha de", origen, "a", destino)
    hanoi(fichas - 1, 6 - origen - destino, destino)

hanoi(5,1,3)
# Out:
# Llevar la ficha de 1 a 3
# Llevar la ficha de 1 a 2
# Llevar la ficha de 3 a 2
# Llevar la ficha de 1 a 3
# Llevar la ficha de 2 a 1
# Llevar la ficha de 2 a 3
# Llevar la ficha de 1 a 3
# Llevar la ficha de 1 a 2
# Llevar la ficha de 3 a 2
# Llevar la ficha de 3 a 1
# Llevar la ficha de 2 a 1
# Llevar la ficha de 3 a 2
# Llevar la ficha de 1 a 3
# Llevar la ficha de 1 a 2
# Llevar la ficha de 3 a 2
# Llevar la ficha de 1 a 3
# Llevar la ficha de 2 a 1
# Llevar la ficha de 2 a 3
# Llevar la ficha de 1 a 3
# Llevar la ficha de 2 a 1
# Llevar la ficha de 3 a 2
# Llevar la ficha de 3 a 1
# Llevar la ficha de 2 a 1
# Llevar la ficha de 2 a 3
# Llevar la ficha de 1 a 3
# Llevar la ficha de 1 a 2
# Llevar la ficha de 3 a 2
# Llevar la ficha de 1 a 3
# Llevar la ficha de 2 a 1
# Llevar la ficha de 2 a 3
# Llevar la ficha de 1 a 3

# %%
# VUELTA ATRAS: problema de las reinas
def reinas(N, solucion, etapa):
  for i in range(N + 1):
    solucion[etapa] = i
    # print(solucion)

    if es_prometedor(solucion, etapa) : 
      if etapa == N - 1:
        print("-> [S] la sol es", solucion)
        return solucion
      else:
        print("-> [P] prometedora")
        reinas(N, solucion, etapa + 1)
    else:
        print("-> [N] no prometedora")
        pass
    
    solucion[etapa] = 0

def es_prometedor(solucion, etapa) : 
  # si la solucion tiene dos valores iguales no es valida
  for i in range(etapa + 1):
    if solucion.count(solucion[i]) > 1:
      return False

    # diagonales
    for j in range(i+1, etapa + 1):
      print("comprueba diagonal de ", i , "y", j)
      if abs(i-j) == abs(solucion[i] - solucion[j]):
        return False
  
  return True

solucion = reinas(4, [0,0,0,0], 0)
print(solucion)
# Out:
# [0, 0, 0, 0]
# -> [N] no prometedora
# [1, 0, 0, 0]
# -> [P] prometedora
# [1, 0, 0, 0]
# comprueba diagonal de  0 y 1
# -> [N] no prometedora
# [1, 1, 0, 0]
# -> [N] no prometedora
# [1, 2, 0, 0]
# comprueba diagonal de  0 y 1
# -> [N] no prometedora
# [1, 3, 0, 0]
# comprueba diagonal de  0 y 1
# -> [P] prometedora
# [1, 3, 0, 0]
# comprueba diagonal de  0 y 1
# comprueba diagonal de  0 y 2
# comprueba diagonal de  1 y 2
# -> [N] no prometedora
# [1, 3, 1, 0]
# -> [N] no prometedora
# [1, 3, 2, 0]
# comprueba diagonal de  0 y 1
# comprueba diagonal de  0 y 2
# comprueba diagonal de  1 y 2
# -> [N] no prometedora
# [1, 3, 3, 0]
# comprueba diagonal de  0 y 1
# comprueba diagonal de  0 y 2
# -> [N] no prometedora
# [1, 3, 4, 0]
# comprueba diagonal de  0 y 1
# comprueba diagonal de  0 y 2
# comprueba diagonal de  1 y 2
# -> [N] no prometedora
# [1, 4, 0, 0]
# comprueba diagonal de  0 y 1
# -> [P] prometedora
# [1, 4, 0, 0]
# comprueba diagonal de  0 y 1
# comprueba diagonal de  0 y 2
# comprueba diagonal de  1 y 2
# -> [N] no prometedora
# [1, 4, 1, 0]
# -> [N] no prometedora
# [1, 4, 2, 0]
# comprueba diagonal de  0 y 1
# comprueba diagonal de  0 y 2
# comprueba diagonal de  1 y 2
# -> [P] prometedora
# [1, 4, 2, 0]
# comprueba diagonal de  0 y 1
# comprueba diagonal de  0 y 2
# comprueba diagonal de  0 y 3
# comprueba diagonal de  1 y 2
# comprueba diagonal de  1 y 3
# comprueba diagonal de  2 y 3
# -> [S] la sol es [1, 4, 2, 0]
# [1, 4, 3, 0]
# comprueba diagonal de  0 y 1
# comprueba diagonal de  0 y 2
# -> [N] no prometedora
# [1, 4, 4, 0]
# comprueba diagonal de  0 y 1
# comprueba diagonal de  0 y 2
# -> [N] no prometedora
# [2, 0, 0, 0]
# -> [P] prometedora
# [2, 0, 0, 0]
# comprueba diagonal de  0 y 1
# -> [N] no prometedora
# [2, 1, 0, 0]
# comprueba diagonal de  0 y 1
# -> [N] no prometedora
# [2, 2, 0, 0]
# -> [N] no prometedora
# [2, 3, 0, 0]
# comprueba diagonal de  0 y 1
# -> [N] no prometedora
# [2, 4, 0, 0]
# comprueba diagonal de  0 y 1
# -> [P] prometedora
# [2, 4, 0, 0]
# comprueba diagonal de  0 y 1
# comprueba diagonal de  0 y 2
# -> [N] no prometedora
# [2, 4, 1, 0]
# comprueba diagonal de  0 y 1
# comprueba diagonal de  0 y 2
# comprueba diagonal de  1 y 2
# -> [P] prometedora
# [2, 4, 1, 0]
# comprueba diagonal de  0 y 1
# comprueba diagonal de  0 y 2
# comprueba diagonal de  0 y 3
# comprueba diagonal de  1 y 2
# comprueba diagonal de  1 y 3
# comprueba diagonal de  2 y 3
# -> [N] no prometedora
# [2, 4, 1, 1]
# comprueba diagonal de  0 y 1
# comprueba diagonal de  0 y 2
# comprueba diagonal de  0 y 3
# comprueba diagonal de  1 y 2
# comprueba diagonal de  1 y 3
# -> [N] no prometedora
# [2, 4, 1, 2]
# -> [N] no prometedora
# [2, 4, 1, 3]
# comprueba diagonal de  0 y 1
# comprueba diagonal de  0 y 2
# comprueba diagonal de  0 y 3
# comprueba diagonal de  1 y 2
# comprueba diagonal de  1 y 3
# comprueba diagonal de  2 y 3
# -> [S] la sol es [2, 4, 1, 3]
# [2, 4, 2, 3]
# -> [N] no prometedora
# [2, 4, 3, 3]
# comprueba diagonal de  0 y 1
# comprueba diagonal de  0 y 2
# comprueba diagonal de  1 y 2
# -> [N] no prometedora
# [2, 4, 4, 3]
# comprueba diagonal de  0 y 1
# comprueba diagonal de  0 y 2
# -> [N] no prometedora
# [3, 0, 0, 3]
# -> [N] no prometedora
# [4, 0, 0, 3]
# -> [P] prometedora
# [4, 0, 0, 3]
# comprueba diagonal de  0 y 1
# -> [N] no prometedora
# [4, 1, 0, 3]
# comprueba diagonal de  0 y 1
# -> [P] prometedora
# [4, 1, 0, 3]
# comprueba diagonal de  0 y 1
# comprueba diagonal de  0 y 2
# comprueba diagonal de  1 y 2
# -> [N] no prometedora
# [4, 1, 1, 3]
# comprueba diagonal de  0 y 1
# comprueba diagonal de  0 y 2
# -> [N] no prometedora
# [4, 1, 2, 3]
# comprueba diagonal de  0 y 1
# comprueba diagonal de  0 y 2
# -> [N] no prometedora
# [4, 1, 3, 3]
# comprueba diagonal de  0 y 1
# comprueba diagonal de  0 y 2
# comprueba diagonal de  1 y 2
# -> [N] no prometedora
# [4, 1, 4, 3]
# -> [N] no prometedora
# [4, 2, 0, 3]
# comprueba diagonal de  0 y 1
# -> [P] prometedora
# [4, 2, 0, 3]
# comprueba diagonal de  0 y 1
# comprueba diagonal de  0 y 2
# comprueba diagonal de  1 y 2
# -> [P] prometedora
# [4, 2, 0, 0]
# comprueba diagonal de  0 y 1
# comprueba diagonal de  0 y 2
# comprueba diagonal de  0 y 3
# comprueba diagonal de  1 y 2
# comprueba diagonal de  1 y 3
# -> [N] no prometedora
# [4, 2, 0, 1]
# comprueba diagonal de  0 y 1
# comprueba diagonal de  0 y 2
# comprueba diagonal de  0 y 3
# -> [N] no prometedora
# [4, 2, 0, 2]
# comprueba diagonal de  0 y 1
# comprueba diagonal de  0 y 2
# comprueba diagonal de  0 y 3
# -> [N] no prometedora
# [4, 2, 0, 3]
# comprueba diagonal de  0 y 1
# comprueba diagonal de  0 y 2
# comprueba diagonal de  0 y 3
# comprueba diagonal de  1 y 2
# comprueba diagonal de  1 y 3
# comprueba diagonal de  2 y 3
# -> [S] la sol es [4, 2, 0, 3]
# [4, 2, 1, 3]
# comprueba diagonal de  0 y 1
# comprueba diagonal de  0 y 2
# comprueba diagonal de  1 y 2
# -> [N] no prometedora
# [4, 2, 2, 3]
# comprueba diagonal de  0 y 1
# comprueba diagonal de  0 y 2
# -> [N] no prometedora
# [4, 2, 3, 3]
# comprueba diagonal de  0 y 1
# comprueba diagonal de  0 y 2
# comprueba diagonal de  1 y 2
# -> [N] no prometedora
# [4, 2, 4, 3]
# -> [N] no prometedora
# [4, 3, 0, 3]
# comprueba diagonal de  0 y 1
# -> [N] no prometedora
# [4, 4, 0, 3]
# -> [N] no prometedora
# None
